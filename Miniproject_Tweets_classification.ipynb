# %% [markdown]
# <a href="https://colab.research.google.com/github/AniketJoshi111/DSBDA_MiniProjects/blob/main/Miniproject_Tweets_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Read dataset

# %%
from google.colab import files

uploaded_files = files.upload()
# Out:
#      <input type="file" id="files-61c4b197-c557-46e6-9036-20b93796a1de" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-61c4b197-c557-46e6-9036-20b93796a1de">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

df = pd.read_csv('data_visualization.csv')


df.drop(columns=['geo' , 'source' , 'thumbnail','near','retweet_id'])
# Out:
# <ipython-input-26-891fc2336cfe>:3: DtypeWarning: Columns (22,24) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('data_visualization.csv')
#                         id      conversation_id               created_at  \
# 0      1406335989484822531  1406335989484822531  2021-06-20 01:10:03 IST
# 1      1406292636789526537  1406292636789526537  2021-06-19 22:17:46 IST
# 2      1406082288035811330  1406082288035811330  2021-06-19 08:21:55 IST
# 3      1405948260796100610  1405948260796100610  2021-06-18 23:29:21 IST
# 4      1405942146960613376  1405942146960613376  2021-06-18 23:05:03 IST
# ...                    ...                  ...                      ...
# 33585           7421815845           7421815845  2010-01-06 06:13:47 IST
# 33586           7416719938           7416719938  2010-01-06 03:24:09 IST
# 33587           7411837095           7411837095  2010-01-06 00:29:44 IST
# ...

# %%
df = df['tweet']

display(df.head())
# Out:
# 0    Take your storytelling to the next level using...
# 1    Choosing Fonts for Your Data Visualization | b...
# 2    This data visualization shows where our greate...
# 3    Looking for examples of stellar charts made so...
# 4    With #WISQARS Data Visualization, you can disp...
# Name: tweet, dtype: object
